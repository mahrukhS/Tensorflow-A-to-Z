# %% [markdown]
# <a href="https://colab.research.google.com/github/mahrukhS/Tensorflow-A-to-Z/blob/main/wiki40b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/drive')

import datasets
import tensorflow_datasets as tfds
import os

# Set the data directory in your Google Drive
drive_data_dir = 'drive/MyDrive/wiki40b_dataset'

# Choose a language from the available configs
language_config = 'en'  # You can choose a different language code

# Create the directory if it doesn't exist
os.makedirs(drive_data_dir, exist_ok=True)

# Load the dataset and store it in Google Drive
dataset_name = f'huggingface:wiki40b/{language_config}'
split = 'train'  # You can change the split as needed

# Load the dataset and specify the data_dir
dataset, info = tfds.load(name=dataset_name, split=split, data_dir=drive_data_dir, with_info=True)

# Display dataset info
print(info)
# Out:
# ...
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/9.42G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/527M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/522M [00:00<?, ?B/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling drive/MyDrive/wiki40b_dataset/wiki40b/en/1.1.0.incompleteT6UB7U/wiki40b-train.tfrecord*...:   0%|   …
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling drive/MyDrive/wiki40b_dataset/wiki40b/en/1.1.0.incompleteT6UB7U/wiki40b-validation.tfrecord*...:   0…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling drive/MyDrive/wiki40b_dataset/wiki40b/en/1.1.0.incompleteT6UB7U/wiki40b-test.tfrecord*...:   0%|    …
# Dataset wiki40b downloaded and prepared to drive/MyDrive/wiki40b_dataset/wiki40b/en/1.1.0. Subsequent calls will reuse this data.
# tfds.core.DatasetInfo(
# ...
